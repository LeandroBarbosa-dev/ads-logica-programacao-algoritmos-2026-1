# %% [markdown]
# ### 2. O CICLO DE PROCESSAMENTO DE DADOS

# %% [markdown]
# ### O Primeiro Programa!
# Olá, mundo!

# %%
print('Olá, mundo!')

# %% [markdown]
# Atenção!

# %%
Print('Olá, mundo!')

# %% [markdown]
# ### Função de Saída

# %% [markdown]
# Podemos usar aspas duplas:

# %%
print("Olá, mundo!")

# %% [markdown]
# Operações aritmética

# %%
print(2 + 3)

# %% [markdown]
# O que acontece aqui?

# %%
print('2 + 3')

# %% [markdown]
# E aqui? Acontece uma concatenação.

# %%
print('2' + '3')

# %% [markdown]
# Concatenando mensagens:

# %%
print('Olá, ' + 'mundo!')
print('Olá,', 'mundo!')

# %% [markdown]
# Concatenado mensagens e números:

# %%
print('O resultado da soma 2 + 3 é:', 2 + 3)

# %% [markdown]
# ### Operadores e operções matemáticas

# %%
print(10 * (5 + 7) / 4)

# %% [markdown]
# Cuidado!!

# %%
print(10 * (5 + 7 / 4))
